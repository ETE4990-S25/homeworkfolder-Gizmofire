# %% [markdown]
# # Gordon lau REDO
#
#
# # Homework #3:
# Creating and Using Python Classes with JSON
#
# ## Instructions:
# ### 1. Create a Python file named `data_classes.py` with the following content:
# - Define a class `Person` with attributes `name`, `age`, and `email`.
# - Define a class `Student` that inherits from `Person` and adds an attribute `student_id`.
# - Include a method to save the data of these instances into a JSON file.
# - Include a method to display the JSON content on the screen.
#
#
# hints:
# ```python
# class Person(object):
#     #do stuff
#
# class Student(Person):
#     #do stuff
#
#
# #use json.dump
# 'last_name': fake.last_name()
# 'first_name': fake.first_name()
# 'email': fake.email()
# 'student_id': fake.age
# ```
#
# ### 2. Write a Jupyter Notebook that:
# - Imports the classes from `data_classes.py`.
# - Creates instances of `Person` and `Student`.
#  - Calls the methods to save data to a JSON file and display the JSON content.
#
# ```python
# from data_classes import Student as dc
# from data_classes import Saver
# bill = dc("bill",12,"bill@cool.com",1234)
# saver(bill)
# ```
#
# ###  Step 3: Verify the JSON file content
# This step should be done by running the display_json method in the Jupyter Notebook I expect you to use your Jupyter notebook to explain any work and thought processes you had while working on your Homework. Consider your Jupyter notebook your "Lab Report" and the Homework is your .py file.

# %% [markdown]
# Your json file should look like the following when you are done
#
# ```JSON
# [
#     {
#         "last_name": "Taylor",
#         "first_name": "Jose",
#         "street_address": "571 Travis Forest Suite 210",
#         "email": "marysanchez@example.org", "age": "Saturday 30. August 2008", "index": 0
#     },
#     {
#         "last_name": "Stevenson",
#         "first_name": "Tyler",
#         "street_address": "529 Washington Neck",
#         "email": "leekatrina@example.org",
#         "age": "Wednesday 25. January 1995",
#         "index": 1
#     }
# ]
# ```

# %% [markdown]
# # NOTE: HAD TO REDO DUE TO POTIENTAL OF SOMEONE ELSE COPYING AND PASTING MY CODE
#
# ## Objectives
# 1. Classes
# 2. Inheritance
# 3. Writing to file as json
# 4. Imports
#
# ## Notes
#     check out the data_classes_redo file for all methods called

# %%
from data_classes_redo import *


    
p1 = Person("Jane", 18)
p2 = Adult("Bass" , 12, "Chef")
p3 = Kid("Joe", 10, 3.0, "cpp highschool")

p1.saver()
p2.saver()
p3.saver()

p1.get_older()
p1.toString

p2.get_older()
p2.change_profession("Janitor")
p2.toString

p3.get_older()
p3.study()
p3.toString()


p1.saver()
p2.saver()
p3.saver()

combined_data = [
    p1.__dict__,
    p2.__dict__,
    p3.__dict__

]
combined_json = json.dumps(combined_data )
saver(combined_data, "all data")
# Out:
# json:
#  {
#     "name": "Jane",
#     "age": 18
# }
# json wrote to file
# json:
#  {
#     "name": "Bass",
#     "age": 12,
#     "profession": "Chef"
# }
# json wrote to file
# json:
#  {
#     "name": "Joe",
#     "age": 10,
#     "gpa": 3.0,
#     "school": "cpp highschool"
# }
# json wrote to file
# Jane, It has been a good year
# Bass, It has been a good year
# Joe, It has been a good year
# Joe has now studyed
# print:
#  {
#     "name": "Joe",
#     "age": 11,
#     "gpa": 3.1,
#     "school": "cpp highschool"
# }
# json:
#  {
#     "name": "Jane",
#     "age": 19
# }
# json wrote to file
# json:
#  {
#     "name": "Bass",
#     "age": 13,
#     "profession": "Janitor"
# }
# json wrote to file
# json:
#  {
#     "name": "Joe",
#     "age": 11,
#     "gpa": 3.1,
#     "school": "cpp highschool"
# }
# json wrote to file
# json:
#  [
#     {
#         "name": "Jane",
#         "age": 19
#     },
#     {
#         "name": "Bass",
#         "age": 13,
#         "profession": "Janitor"
#     },
#     {
#         "name": "Joe",
#         "age": 11,
#         "gpa": 3.1,
#         "school": "cpp highschool"
#     }
# ]
# json wrote to file
# json:
#  {
#     "name": "Jane",
#     "age": 18
# }
# json wrote to file
# json:
#  {
#     "name": "Bass",
#     "age": 12,
#     "profession": "Chef"
# }
# json wrote to file
# json:
#  {
#     "name": "Joe",
#     "age": 10,
#     "gpa": 3.0,
#     "school": "cpp highschool"
# }
# json wrote to file
# Jane, It has been a good year
# Bass, It has been a good year
# Joe, It has been a good year
# Joe has now studyed
# print:
#  {
#     "name": "Joe",
#     "age": 11,
#     "gpa": 3.1,
#     "school": "cpp highschool"
# }
# json:
#  {
#     "name": "Jane",
#     "age": 19
# }
# json wrote to file
# json:
#  {
#     "name": "Bass",
#     "age": 13,
#     "profession": "Janitor"
# }
# json wrote to file
# json:
#  {
#     "name": "Joe",
#     "age": 11,
#     "gpa": 3.1,
#     "school": "cpp highschool"
# }
# json wrote to file
# json:
#  [
#     {
#         "name": "Jane",
#         "age": 19
#     },
#     {
#         "name": "Bass",
#         "age": 13,
#         "profession": "Janitor"
#     },
#     {
#         "name": "Joe",
#         "age": 11,
#         "gpa": 3.1,
#         "school": "cpp highschool"
#     }
# ]
# json wrote to file
