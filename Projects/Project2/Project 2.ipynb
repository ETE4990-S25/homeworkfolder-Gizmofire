# %% [markdown]
# ## Project # 2
#
# Create a Multiprocessing, Threaded and Asynchronous application that will calculate the highest prime number in 3 min.
#
# You must start a 0
#
# After you have created these programs analyze  the performance of each. IE: How long did it take to find prime number? Compare each prime and why each found that prime number.
#
# If you wish you can calculate any other non dependent item and them perform analyses.
#
# For code consistancy use the following is_prime function.
# ```python
# def is_prime(n):
#     if n <= 1:
#         return False
#     for i in range(2, int(n ** 0.5) + 1):
#         if n % i == 0:
#             return False
#     return True
# ```
#     async       13,386,001
#     threaded(2) 10,747,921

# %%
def getStuff (Lists):
    list1 = []
    for List in Lists:
        if (Lists[0] == 4):
            list1.append(List);
    return list1;

# %%
getStuff([1,2,3,4,5])

# %%
a = 1
for i in range(a,4):
    print(i)

    print(i)

# %% [markdown]
# New Directions !!!
#
#
#
# Part 1
# Run Multiprocessing, Threaded and Asynchronous code to find the highest prime number in 3 minutes.
#
# Part 2
# Analyze the performance of operations.
#
#     - How long did it take to find the prime number.
#     - Finding Fib of prime number
#     - Finding Factorial of prime number

# %% [markdown]
# Mutlicore
# ![multicire.png](attachment:multicire.png)

# %% [markdown]
# aSYNC
# ![async.png](attachment:async.png)

# %% [markdown]
# multithread
# ![multithread.png](attachment:multithread.png)

# %% [markdown]
# Analyzed results of higest prime number found.
#
#
# ``` powershell
# Main program started at: 2025-04-05 03:16:13.518955
# Starting processes...
# Task 1 (fibTest) started at: 2025-04-05 03:16:13.520046
# The Fibonacci number at position 1 is 1
# Task 2 (factorial_test) started at: 2025-04-05 03:16:13.520046
# The Fibonacci number at position 2 is 1
# The Fact number at position 1 is 1
# The Fibonacci number at position 3 is 2
# The Fact number at position 2 is 2
# The Fibonacci number at position 4 is 3
# The Fact number at position 3 is 6
# The Fact number at position 4 is 24
# The Fibonacci number at position 5 is 5
# The Fibonacci number at position 6 is 8
# The Fact number at position 5 is 120
# The Fact number at position 6 is 720
# The Fibonacci number at position 7 is 13
# The Fibonacci number at position 8 is 21
# The Fact number at position 7 is 5040
# The Fibonacci number at position 9 is 34
# The Fact number at position 8 is 40320
# The Fact number at position 9 is 362880
# The Fibonacci number at position 10 is 55
# The Fact number at position 10 is 3628800
# The Fibonacci number at position 11 is 89
# Task 2 (factorial_test) finished at: 2025-04-05 03:16:13.521044
# The Fibonacci number at position 12 is 144
# Task 2 (factorial_test) duration: 0:00:00.000998
# The Fibonacci number at position 13 is 233
# The Fibonacci number at position 14 is 377
# The Fibonacci number at position 15 is 610
# The Fibonacci number at position 16 is 987
# The Fibonacci number at position 17 is 1597
# The Fibonacci number at position 18 is 2584
# The Fibonacci number at position 19 is 4181
# The Fibonacci number at position 20 is 6765
# The Fibonacci number at position 21 is 10946
# The Fibonacci number at position 22 is 17711
# The Fibonacci number at position 23 is 28657
# The Fibonacci number at position 24 is 46368
# The Fibonacci number at position 25 is 75025
# The Fibonacci number at position 26 is 121393
# The Fibonacci number at position 27 is 196418
# The Fibonacci number at position 28 is 317811
# The Fibonacci number at position 29 is 514229
# The Fibonacci number at position 30 is 832040
# The Fibonacci number at position 31 is 1346269
# The Fibonacci number at position 32 is 2178309
# The Fibonacci number at position 33 is 3524578
# The Fibonacci number at position 34 is 5702887
# Task 1 (fibTest) finished at: 2025-04-05 03:16:16.942112
# Task 1 (fibTest) duration: 0:00:03.422066
# Processes finished.
# Main program finished at: 2025-04-05 03:16:16.942112
# Total main program duration: 0:00:03.423157

# %% [markdown]
# ## Conclusion
#
# Factorial is calculated in 0.000998 seconds, while Fibonacci is calculated in 3.422066 seconds.
# Even whent the tasks are run in parallel, the Fibonacci task takes longer to complete than the Factorial task.
# We can see in the results produced where after Fib 10 the time taken to calculate the Fibonacci number increases significantly.
